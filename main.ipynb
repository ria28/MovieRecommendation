# %%
# !pip install flask-ngrok

# %%
# !python '/content/drive/MyDrive/Colab Notebooks/AJAX-Movie-Recommendation-System-with-Sentiment-Analysis-master/main.py'
# Out:
#  * Serving Flask app "main" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://b2cd3d067c03.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [31/Dec/2020 11:55:43] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:55:44] "GET /static/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:55:44] "GET /static/recommend.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:55:45] "GET /static/autocomplete.js HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:55:45] "GET /static/image.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [31/Dec/2020 11:55:47] "GET /favicon.ico HTTP/1.1" 404 -
# ^C
