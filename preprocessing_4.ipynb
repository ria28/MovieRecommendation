# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request

# %% [markdown]
# ## Extracting features of 2020 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
type(tables[0])
# Out:
# bs4.element.Tag

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  ...   Ref.
# 0     JANUARY  ...    [2]
# 1     JANUARY  ...    [3]
# 2     JANUARY  ...    [4]
# 3     JANUARY  ...    NaN
# 4     JANUARY  ...    [5]
# ..        ...  ...    ...
# 264  DECEMBER  ...  [237]
# 265  DECEMBER  ...  [238]
# 266  DECEMBER  ...  [239]
# 267  DECEMBER  ...  [240]
# 268  DECEMBER  ...  [241]
#
# [269 rows x 6 columns]

# %%
df_2020 = df[['Title','Cast and crew']]

# %%
df_2020
# Out:
#                      Title                                      Cast and crew
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 264       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 265      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 266  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 267     One Night in Miami  Regina King (director); Kemp Powers (screenpla...
# 268      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
# [269 rows x 2 columns]

# %%
# !pip install tmdbv3api

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'a3e72eb85eec51be83604072de949a39'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    if not result:
      return np.NaN
    else:
      movie_id = result[0].id
      response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
      data_json = response.json()
      if data_json['genres']:
          genre_str = " " 
          for i in range(0,len(data_json['genres'])):
              genres.append(data_json['genres'][i]['name'])
          return genre_str.join(genres)
      else:
          return np.NaN

# %%
df_2020['genres'] = df_2020['Title'].map(lambda x: get_genre(str(x)))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2020
# Out:
#                      Title  ...                                  genres
# 0               The Grudge  ...                 Horror Mystery Thriller
# 1               Underwater  ...  Action Horror Science Fiction Thriller
# 2              Like a Boss  ...                                  Comedy
# 3            Three Christs  ...                                   Drama
# 4        Inherit the Viper  ...                    Drama Thriller Crime
# ..                     ...  ...                                     ...
# 264       We Can Be Heroes  ...                   Action Fantasy Family
# 265      News of the World  ...                           Drama Western
# 266  Promising Young Woman  ...                    Thriller Crime Drama
# 267     One Night in Miami  ...                                   Drama
# 268      Pieces of a Woman  ...                                   Drama
#
# [269 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2020
# Out:
#                      Title  ...     actor_3_name
# 0               The Grudge  ...         John Cho
# 1               Underwater  ...  Jessica Henwick
# 2              Like a Boss  ...      Salma Hayek
# 3            Three Christs  ...   Walton Goggins
# 4        Inherit the Viper  ...   Chandler Riggs
# ..                     ...  ...              ...
# 264       We Can Be Heroes  ...    YaYa Gosselin
# 265      News of the World  ...              NaN
# 266  Promising Young Woman  ...      Alison Brie
# 267     One Night in Miami  ...      Aldis Hodge
# 268      Pieces of a Woman  ...     Molly Parker
#
# [269 rows x 7 columns]

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20
# Out:
#         director_name  ...            movie_title
# 0       Nicolas Pesce  ...             The Grudge
# 1      William Eubank  ...             Underwater
# 2       Miguel Arteta  ...            Like a Boss
# 3           Jon Avnet  ...          Three Christs
# 4      Anthony Jerjen  ...      Inherit the Viper
# ..                ...  ...                    ...
# 264  Robert Rodriguez  ...       We Can Be Heroes
# 265   Paul Greengrass  ...      News of the World
# 266   Emerald Fennell  ...  Promising Young Woman
# 267       Regina King  ...     One Night in Miami
# 268  Kornél Mundruczó  ...      Pieces of a Woman
#
# [269 rows x 6 columns]

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']

# %%
new_df20.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      3
# actor_3_name     26
# genres            1
# movie_title       0
# comb             27
# dtype: int64

# %%
new_df20 = new_df20.dropna(how='any')

# %%
new_df20.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df20
# Out:
#         director_name  ...                                               comb
# 0       Nicolas Pesce  ...  Andrea Riseborough Demián Bichir John Cho Nico...
# 1      William Eubank  ...  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2       Miguel Arteta  ...  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3           Jon Avnet  ...  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4      Anthony Jerjen  ...  Josh Hartnett Margarita Levieva Chandler Riggs...
# ..                ...  ...                                                ...
# 263       Pete Docter  ...  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 264  Robert Rodriguez  ...  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 266   Emerald Fennell  ...  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 267       Regina King  ...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 268  Kornél Mundruczó  ...  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [242 rows x 7 columns]

# %%
old_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AJAX-Movie-Recommendation-System-with-Sentiment-Analysis-master/datasets/final_data.csv')

# %%
old_df
# Out:
#               director_name  ...                                               comb
# 0             James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James C...
# 1            Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2                Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3         Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4               Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                     ...  ...                                                ...
# 5865           Greta Gerwig  ...  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5866             Sam Mendes  ...  George MacKay Dean-Charles Chapman Mark Strong...
# 5867  Destin Daniel Cretton  ...  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5868        Chinonye Chukwu  ...  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# ...

# %%
final_df = old_df.append(new_df20,ignore_index=True)

# %%
final_df
# Out:
#           director_name  ...                                               comb
# 0         James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James C...
# 1        Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2            Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4           Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                 ...  ...                                                ...
# 6107        Pete Docter  ...  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 6108   Robert Rodriguez  ...  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6109    Emerald Fennell  ...  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6110        Regina King  ...  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6111   Kornél Mundruczó  ...  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# ...

# %%
final_df.to_csv('/content/drive/MyDrive/Colab Notebooks/AJAX-Movie-Recommendation-System-with-Sentiment-Analysis-master/datasets/main_data.csv',index=False)
