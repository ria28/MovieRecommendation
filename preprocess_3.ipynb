# %%
# !nvidia-smi

# %%
# !pip install tensorflow-gpu

# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  ...   Ref.
# 0     JANUARY  ...    [2]
# 1     JANUARY  ...    [3]
# 2     JANUARY  ...    [4]
# 3     JANUARY  ...    [5]
# 4     JANUARY  ...    [6]
# ..        ...  ...    ...
# 263  DECEMBER  ...  [162]
# 264  DECEMBER  ...  [136]
# 265  DECEMBER  ...  [224]
# 266  DECEMBER  ...  [256]
# 267  DECEMBER  ...  [257]
#
# [268 rows x 6 columns]

# %%
# !pip install tmdbv3api
# Out:
# Collecting tmdbv3api
#   Downloading https://files.pythonhosted.org/packages/5b/d4/a7addb31f90ca09a7cb102b584083201c158e2818b5e4494c98aebe30fc2/tmdbv3api-1.7.2-py2.py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from tmdbv3api) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbv3api) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbv3api) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbv3api) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->tmdbv3api) (1.24.3)
# Installing collected packages: tmdbv3api
# Successfully installed tmdbv3api-1.7.2

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'a3e72eb85eec51be83604072de949a39'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  ...                                           genres
# 0     JANUARY  ...                          Horror Mystery Thriller
# 1     JANUARY  ...                                   Thriller Drama
# 2     JANUARY  ...                                  Action Thriller
# 3     JANUARY  ...                            Drama History Western
# 4     JANUARY  ...                                  Action Thriller
# ..        ...  ...                                              ...
# 263  DECEMBER  ...                   Mystery Adventure Comedy Crime
# 264  DECEMBER  ...                            Action Crime Thriller
# 265  DECEMBER  ...                                    Drama History
# 266  DECEMBER  ...                         Adventure Fantasy Action
# 267  DECEMBER  ...  Science Fiction Mystery Drama Thriller TV Movie
#
# [268 rows x 7 columns]

# %%
df_2018 = df[['Title','Cast and crew','genres']]

# %%
df_2018
# Out:
#                           Title  ...                                           genres
# 0       Insidious: The Last Key  ...                          Horror Mystery Thriller
# 1              The Strange Ones  ...                                   Thriller Drama
# 2                      Stratton  ...                                  Action Thriller
# 3                 Sweet Country  ...                            Drama History Western
# 4                  The Commuter  ...                                  Action Thriller
# ..                          ...  ...                                              ...
# 263             Holmes & Watson  ...                   Mystery Adventure Comedy Crime
# 264                        Vice  ...                            Action Crime Thriller
# 265         On the Basis of Sex  ...                                    Drama History
# 266                   Destroyer  ...                         Adventure Fantasy Action
# 267  Black Mirror: Bandersnatch  ...  Science Fiction Mystery Drama Thriller TV Movie
#
# [268 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018
# Out:
#                           Title  ...    actor_3_name
# 0       Insidious: The Last Key  ...  Leigh Whannell
# 1              The Strange Ones  ...   Emily Althaus
# 2                      Stratton  ...      Gemma Chan
# 3                 Sweet Country  ...             NaN
# 4                  The Commuter  ...  Patrick Wilson
# ..                          ...  ...             ...
# 263             Holmes & Watson  ...    Rebecca Hall
# 264                        Vice  ...    Steve Carell
# 265         On the Basis of Sex  ...  Justin Theroux
# 266                   Destroyer  ...    Toby Kebbell
# 267  Black Mirror: Bandersnatch  ...   Asim Chaudhry
#
# [268 rows x 7 columns]

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18
# Out:
#           director_name  ...                 movie_title
# 0          Adam Robitel  ...     Insidious: The Last Key
# 1      Lauren Wolkstein  ...            The Strange Ones
# 2            Simon West  ...                    Stratton
# 3      Warwick Thornton  ...               Sweet Country
# 4    Jaume Collet-Serra  ...                The Commuter
# ..                  ...  ...                         ...
# 263          Etan Cohen  ...             Holmes & Watson
# 264          Adam McKay  ...                        Vice
# 265          Mimi Leder  ...         On the Basis of Sex
# 266        Karyn Kusama  ...                   Destroyer
# 267         David Slade  ...  Black Mirror: Bandersnatch
#
# [268 rows x 6 columns]

# %%
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']

# %%
new_df18
# Out:
#           director_name  ...                                               comb
# 0          Adam Robitel  ...  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1      Lauren Wolkstein  ...  Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2            Simon West  ...  Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3      Warwick Thornton  ...  Bryan Brown Sam Neill unknown Warwick Thornton...
# 4    Jaume Collet-Serra  ...  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                  ...  ...                                                ...
# 263          Etan Cohen  ...  Will Ferrell John C. Reilly Rebecca Hall Etan ...
# 264          Adam McKay  ...  Christian Bale Amy Adams Steve Carell Adam McK...
# 265          Mimi Leder  ...  Felicity Jones Armie Hammer Justin Theroux Mim...
# 266        Karyn Kusama  ...  Nicole Kidman Sebastian Stan Toby Kebbell Kary...
# 267         David Slade  ...  Fionn Whitehead Will Poulter Asim Chaudhry Dav...
#
# [268 rows x 7 columns]

# %% [markdown]
# # **Extracting features of 2019 movies from Wikipedia**

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[3]
df2 = pd.read_html(link, header=0)[4]
df3 = pd.read_html(link, header=0)[5]
df4 = pd.read_html(link, header=0)[6]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  ...   Ref.
# 0     JANUARY  ...    [2]
# 1     JANUARY  ...    [3]
# 2     JANUARY  ...    [4]
# 3     JANUARY  ...    [5]
# 4     JANUARY  ...    [6]
# ..        ...  ...    ...
# 238  DECEMBER  ...  [223]
# 239  DECEMBER  ...  [224]
# 240  DECEMBER  ...  [225]
# 241  DECEMBER  ...  [226]
# 242  DECEMBER  ...  [227]
#
# [243 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2019 = df[['Title','Cast and crew','genres']]

# %%
df_2019
# Out:
#                 Title  ...                                    genres
# 0         Escape Room  ...  Thriller Action Mystery Adventure Horror
# 1          Rust Creek  ...                            Thriller Drama
# 2    American Hangman  ...                                  Thriller
# 3    A Dog's Way Home  ...                    Drama Adventure Family
# 4          The Upside  ...                              Comedy Drama
# ..                ...  ...                                       ...
# 238      Little Women  ...                             Drama Romance
# 239              1917  ...                 War Drama Action Thriller
# 240        Just Mercy  ...                                     Drama
# 241          Clemency  ...                                     Drama
# 242        Apparition  ...                           Horror Thriller
#
# [243 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']

# %%
new_df19
# Out:
#              director_name  ...                                               comb
# 0             Adam Robitel  ...  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1              Jen McGowan  ...  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2        Wilson Coneybeare  ...  Donald Sutherland Vincent Kartheiser Oliver De...
# 3     Charles Martin Smith  ...  Bryce Dallas Howard Edward James Olmos Alexand...
# 4              Neil Burger  ...  Bryan Cranston Kevin Hart Nicole Kidman Neil B...
# ..                     ...  ...                                                ...
# 238           Greta Gerwig  ...  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 239             Sam Mendes  ...  George MacKay Dean-Charles Chapman Mark Strong...
# 240  Destin Daniel Cretton  ...  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 241        Chinonye Chukwu  ...  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 242           Waymon Boone  ...  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [243 rows x 7 columns]

# %%
my_df = new_df18.append(new_df19,ignore_index=True)
my_df
# Out:
#              director_name  ...                                               comb
# 0             Adam Robitel  ...  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1         Lauren Wolkstein  ...  Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2               Simon West  ...  Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3         Warwick Thornton  ...  Bryan Brown Sam Neill unknown Warwick Thornton...
# 4       Jaume Collet-Serra  ...  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...
# ..                     ...  ...                                                ...
# 506           Greta Gerwig  ...  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 507             Sam Mendes  ...  George MacKay Dean-Charles Chapman Mark Strong...
# 508  Destin Daniel Cretton  ...  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 509        Chinonye Chukwu  ...  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 510           Waymon Boone  ...  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [511 rows x 7 columns]

# %%
old_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AJAX-Movie-Recommendation-System-with-Sentiment-Analysis-master/datasets/new_data.csv')

# %%
old_df
# Out:
#               director_name  ...                                               comb
# 0             James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James C...
# 1            Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2                Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3         Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4               Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                     ...  ...                                                ...
# 5359            Jim Strouse  ...  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5360            Farhad Mann  ...  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5361       Hannaleena Hauru  ...  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5362  Jonathan A. Rosenbaum  ...  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5363           Ravi Udyawar  ...  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5364 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)
final_df
# Out:
#               director_name  ...                                               comb
# 0             James Cameron  ...  CCH Pounder Joel David Moore Wes Studi James C...
# 1            Gore Verbinski  ...  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2                Sam Mendes  ...  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3         Christopher Nolan  ...  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4               Doug Walker  ...  Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                     ...  ...                                                ...
# 5870           Greta Gerwig  ...  Saoirse Ronan Emma Watson Florence Pugh Greta ...
# 5871             Sam Mendes  ...  George MacKay Dean-Charles Chapman Mark Strong...
# 5872  Destin Daniel Cretton  ...  Michael B. Jordan Jamie Foxx Brie Larson Desti...
# 5873        Chinonye Chukwu  ...  Alfre Woodard Wendell Pierce Aldis Hodge Chino...
# 5874           Waymon Boone  ...  Mena Suvari Kevin Pollak unknown Waymon Boone ...
#
# [5875 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           5
# movie_title      0
# comb             5
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('/content/drive/MyDrive/Colab Notebooks/AJAX-Movie-Recommendation-System-with-Sentiment-Analysis-master/datasets/final_data.csv',index=False)
